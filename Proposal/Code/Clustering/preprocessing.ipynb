# %% [markdown]
# ## Data Preprocessing for the K-means-Clustering

# %%
import pandas as pd

company = pd.read_csv("company.csv")
company
# Out:
#       gu  dong  company
# 0    종로구   사직동     3574
# 1    종로구   삼청동      732
# 2    종로구   부암동      599
# 3    종로구   평창동      761
# 4    종로구   무악동      647
# ..   ...   ...      ...
# 419  강동구  둔촌1동       17
# 420  강동구  둔촌2동     1553
# 421  강동구  암사1동     1918
# 422  강동구  천호2동     3439
# 423  강동구    길동     5037
#
# [424 rows x 3 columns]

# %%
df = pd.read_csv("Income_Pdensity_Zoncode.csv")
df = df.iloc[:, 1:]
df
# Out:
#       gu   dong        code  income_level  pop_density
# 0    종로구  청운효자동  1111051500           8.0         5051
# 1    종로구    사직동  1111053000           9.0         7980
# 2    종로구    삼청동  1111054000           7.0         2011
# 3    종로구    부암동  1111055000           7.0         4648
# 4    종로구    평창동  1111056000           8.0         2121
# ..   ...    ...         ...           ...          ...
# 419  강동구   성내2동  1174065000           6.0        37591
# 420  강동구   성내3동  1174066000           7.0        33692
# 421  강동구     길동  1174068500           7.0        21367
# 422  강동구   둔촌1동  1174069000           7.0          308
# 423  강동구   둔촌2동  1174070000           7.0        28318
#
# [424 rows x 5 columns]

# %%
result_df = pd.merge(df, company, on=['gu', 'dong'], how='left')
result_df
# Out:
#       gu   dong        code  income_level  pop_density  company
# 0    종로구  청운효자동  1111051500           8.0         5051   1028.0
# 1    종로구    사직동  1111053000           9.0         7980   3574.0
# 2    종로구    삼청동  1111054000           7.0         2011    732.0
# 3    종로구    부암동  1111055000           7.0         4648    599.0
# 4    종로구    평창동  1111056000           8.0         2121    761.0
# ..   ...    ...         ...           ...          ...      ...
# 419  강동구   성내2동  1174065000           6.0        37591   1836.0
# 420  강동구   성내3동  1174066000           7.0        33692   2439.0
# 421  강동구     길동  1174068500           7.0        21367   5037.0
# 422  강동구   둔촌1동  1174069000           7.0          308     17.0
# 423  강동구   둔촌2동  1174070000           7.0        28318   1553.0
#
# [424 rows x 6 columns]

# %%
result_df.to_csv("final_data.csv")

# %% [markdown]
# # 각 행정동 x,y좌표 생성하기

# %%
# Assuming your DataFrame is named df
df['address'] = '서울시 ' + df['gu'] + ' ' + df['dong']
df
# Out:
#       gu   dong        code  income_level  pop_density        address
# 0    종로구  청운효자동  1111051500           8.0         5051  서울시 종로구 청운효자동
# 1    종로구    사직동  1111053000           9.0         7980    서울시 종로구 사직동
# 2    종로구    삼청동  1111054000           7.0         2011    서울시 종로구 삼청동
# 3    종로구    부암동  1111055000           7.0         4648    서울시 종로구 부암동
# 4    종로구    평창동  1111056000           8.0         2121    서울시 종로구 평창동
# ..   ...    ...         ...           ...          ...            ...
# 419  강동구   성내2동  1174065000           6.0        37591   서울시 강동구 성내2동
# 420  강동구   성내3동  1174066000           7.0        33692   서울시 강동구 성내3동
# 421  강동구     길동  1174068500           7.0        21367     서울시 강동구 길동
# 422  강동구   둔촌1동  1174069000           7.0          308   서울시 강동구 둔촌1동
# 423  강동구   둔촌2동  1174070000           7.0        28318   서울시 강동구 둔촌2동
#
# [424 rows x 6 columns]

# %%
import requests

def geocode_address(address):
    api_key = 'AIzaSyBygRp967Ub0GG0DVVYOm6OOdivESjR3RQ'
    base_url = 'https://maps.googleapis.com/maps/api/geocode/json'
    
    params = {
        'address': address,
        'key': api_key,
    }
    
    response = requests.get(base_url, params=params)
    data = response.json()
    
    if data['status'] == 'OK':
        location = data['results'][0]['geometry']['location']
        latitude = location['lat']
        longitude = location['lng']
        return latitude, longitude
    else:
        return None

# %%
# 주소를 X좌표와 Y좌표로 변환

result = []
address_li = df["address"]

for address in address_li:
    coordinates = geocode_address(address)
    if coordinates:
        print(f'주소 "{address}"의 지리적 좌표: {coordinates[0]}, {coordinates[1]}')
        result.append(coordinates)
    else:
        print('주소를 변환할 수 없습니다.')
        result.append((None, None))

print()
print(result)
# Out:
# 주소 "서울시 종로구 청운효자동"의 지리적 좌표: 37.5837762, 126.9706629
# 주소 "서울시 종로구 사직동"의 지리적 좌표: 37.5738782, 126.9705612
# 주소 "서울시 종로구 삼청동"의 지리적 좌표: 37.5907651, 126.9810164
# 주소 "서울시 종로구 부암동"의 지리적 좌표: 37.5947594, 126.9655887
# 주소 "서울시 종로구 평창동"의 지리적 좌표: 37.6130288, 126.9745028
# 주소 "서울시 종로구 무악동"의 지리적 좌표: 37.5764425, 126.9593115
# 주소 "서울시 종로구 교남동"의 지리적 좌표: 37.5716359, 126.9639041
# 주소 "서울시 종로구 가회동"의 지리적 좌표: 37.5820119, 126.9864646
# 주소 "서울시 종로구 종로1·2·3·4가동"의 지리적 좌표: 37.5741642, 126.9897294
# 주소를 변환할 수 없습니다.
# 주소 "서울시 종로구 이화동"의 지리적 좌표: 37.5772395, 127.005633
# 주소 "서울시 종로구 혜화동"의 지리적 좌표: 37.5878109, 127.0017424
# 주소를 변환할 수 없습니다.
# 주소 "서울시 종로구 창신2동"의 지리적 좌표: 37.5739234, 127.0104106
# 주소 "서울시 종로구 창신3동"의 지리적 좌표: 37.5789506, 127.0150489
# 주소 "서울시 종로구 숭인1동"의 지리적 좌표: 37.5777841, 127.0156044
# 주소 "서울시 종로구 숭인2동"의 지리적 좌표: 37.5748401, 127.0199652
# 주소 "서울시 중구 소공동"의 지리적 좌표: 37.5644131, 126.9749183
# 주소 "서울시 중구 회현동"의 지리적 좌표: 37.5576619, 126.9776955
# 주소 "서울시 중구 명동"의 지리적 좌표: 37.55998, 126.9858296
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df["coordinates"] = result
df
# Out:
#        gu         dong        code  income_level  pop_density  \
# 0     종로구        청운효자동  1111051500           8.0         5051
# 1     종로구          사직동  1111053000           9.0         7980
# 2     종로구          삼청동  1111054000           7.0         2011
# 3     종로구          부암동  1111055000           7.0         4648
# 4     종로구          평창동  1111056000           8.0         2121
# 5     종로구          무악동  1111057000           9.0        24278
# 6     종로구          교남동  1111058000           8.0        30594
# 7     종로구          가회동  1111060000           7.0         8311
# 8     종로구  종로1·2·3·4가동  1111061500           7.0         3594
# 9     종로구      종로5·6가동  1111063000           6.0         9732
# 10    종로구          이화동  1111064000           7.0        10859
# 11    종로구          혜화동  1111065000           7.0        18246
# 12    종로구         창신1동  1111067000           5.0        19610
# 13    종로구         창신2동  1111068000           5.0        37688
# ...

# %%
df.to_csv("with_coordinates.csv")

# %%
# Assuming 'coordinates' is the name of the column
result = df[df['coordinates'] == (None, None)]

# Display the rows where coordinates are (None, None)
result
# Out:
#        gu     dong        code  income_level  pop_density          address  \
# 9     종로구  종로5·6가동  1111063000           6.0         9732  서울시 종로구 종로5·6가동
# 12    종로구     창신1동  1111067000           5.0        19610     서울시 종로구 창신1동
# 77    광진구     구의1동  1121585000           6.0        41184     서울시 광진구 구의1동
# 90   동대문구     휘경1동  1123072000           6.0        26203    서울시 동대문구 휘경1동
# 100   중랑구     상봉1동  1126058000           7.0        29999     서울시 중랑구 상봉1동
# 107   중랑구     망우3동  1126066000           5.0        18122     서울시 중랑구 망우3동
# 150   도봉구     쌍문1동  1132066000           6.0        18035     서울시 도봉구 쌍문1동
# 246   강서구     화곡3동  1150056000           7.0        44529     서울시 강서구 화곡3동
# 258   강서구     방화2동  1150064000           6.0         3752     서울시 강서구 방화2동
# 312   동작구     사당3동  1159064000           8.0        28298     서울시 동작구 사당3동
# 314   동작구     사당5동  1159065100           7.0        22607     서울시 동작구 사당5동
#
#       coordinates
# 9    (None, None)
# 12   (None, None)
# ...

# %%
# (127.0035339, 37.57061741), (127.016324, 37.5707013), (127.085659, 37.5423990), (127.065708, 37.5929030), (127.087139, 37.5998180), (127.106336, 37.6014603), (127.026028, 37.6480221), (126.838397, 37.5425058), (126.806719, 37.5667035), (126.972019, 37.4866716), (126.966965, 37.4856431)

# %%
# Replace coordinates for specific rows
# replace_values = {
#     9:(127.0035339, 37.57061741),
#     12:(127.016324, 37.5707013),
#     77:(127.085659, 37.5423990),
#     90:(127.065708, 37.5929030),
#     100:(127.087139, 37.5998180),
#     107:(127.106336, 37.6014603),
#     150:(127.026028, 37.6480221),
#     246:(126.838397, 37.5425058),
#     258:(126.806719, 37.5667035),
#     312:(126.972019, 37.4866716),
#     314:(126.966965, 37.4856431)
# }

# for index, value in replace_values.items():
#     df.loc[index, 'coordinates'] = value

# df

# %%
df = pd.read_csv("with_coordinates.csv")
df
# Out:
#      Unnamed: 0    gu         dong        code  income_level  pop_density  \
# 0             0   종로구        청운효자동  1111051500             8         5051
# 1             1   종로구          사직동  1111053000             9         7980
# 2             2   종로구          삼청동  1111054000             7         2011
# 3             3   종로구          부암동  1111055000             7         4648
# 4             4   종로구          평창동  1111056000             8         2121
# 5             5   종로구          무악동  1111057000             9        24278
# 6             6   종로구          교남동  1111058000             8        30594
# 7             7   종로구          가회동  1111060000             7         8311
# 8             8   종로구  종로1·2·3·4가동  1111061500             7         3594
# 9             9   종로구      종로5·6가동  1111063000             6         9732
# 10           10   종로구          이화동  1111064000             7        10859
# 11           11   종로구          혜화동  1111065000             7        18246
# ...

# %%
df[['x', 'y']] = df['coordinates'].str.strip('()').str.split(', ', expand=True).astype(float)

df
# Out:
#      Unnamed: 0    gu         dong        code  income_level  pop_density  \
# 0             0   종로구        청운효자동  1111051500             8         5051
# 1             1   종로구          사직동  1111053000             9         7980
# 2             2   종로구          삼청동  1111054000             7         2011
# 3             3   종로구          부암동  1111055000             7         4648
# 4             4   종로구          평창동  1111056000             8         2121
# 5             5   종로구          무악동  1111057000             9        24278
# 6             6   종로구          교남동  1111058000             8        30594
# 7             7   종로구          가회동  1111060000             7         8311
# 8             8   종로구  종로1·2·3·4가동  1111061500             7         3594
# 9             9   종로구      종로5·6가동  1111063000             6         9732
# 10           10   종로구          이화동  1111064000             7        10859
# 11           11   종로구          혜화동  1111065000             7        18246
# ...

# %%
df = df.drop(columns=['coordinates', df.columns[0]])

df
# Out:
#        gu         dong        code  income_level  pop_density  \
# 0     종로구        청운효자동  1111051500             8         5051
# 1     종로구          사직동  1111053000             9         7980
# 2     종로구          삼청동  1111054000             7         2011
# 3     종로구          부암동  1111055000             7         4648
# 4     종로구          평창동  1111056000             8         2121
# 5     종로구          무악동  1111057000             9        24278
# 6     종로구          교남동  1111058000             8        30594
# 7     종로구          가회동  1111060000             7         8311
# 8     종로구  종로1·2·3·4가동  1111061500             7         3594
# 9     종로구      종로5·6가동  1111063000             6         9732
# 10    종로구          이화동  1111064000             7        10859
# 11    종로구          혜화동  1111065000             7        18246
# 12    종로구         창신1동  1111067000             5        19610
# 13    종로구         창신2동  1111068000             5        37688
# ...

# %%
df.to_csv("real_final.csv")

# %%
df = pd.read_csv("real_final.csv")

# %%
df
# Out:
#      Unnamed: 0   gu   dong        code  income_level  pop_density  \
# 0             0  종로구  청운효자동  1111051500             8         5051
# 1             1  종로구    사직동  1111053000             9         7980
# 2             2  종로구    삼청동  1111054000             7         2011
# 3             3  종로구    부암동  1111055000             7         4648
# 4             4  종로구    평창동  1111056000             8         2121
# ..          ...  ...    ...         ...           ...          ...
# 419         419  강동구   성내2동  1174065000             6        37591
# 420         420  강동구   성내3동  1174066000             7        33692
# 421         421  강동구     길동  1174068500             7        21367
# 422         422  강동구   둔촌1동  1174069000             7          308
# 423         423  강동구   둔촌2동  1174070000             7        28318
#
#            address          x           y
# 0    서울시 종로구 청운효자동  37.583776  126.970663
# 1      서울시 종로구 사직동  37.573878  126.970561
# ...

# %%
df.iloc[:, 1:]
# Out:
#       gu   dong        code  income_level  pop_density        address  \
# 0    종로구  청운효자동  1111051500             8         5051  서울시 종로구 청운효자동
# 1    종로구    사직동  1111053000             9         7980    서울시 종로구 사직동
# 2    종로구    삼청동  1111054000             7         2011    서울시 종로구 삼청동
# 3    종로구    부암동  1111055000             7         4648    서울시 종로구 부암동
# 4    종로구    평창동  1111056000             8         2121    서울시 종로구 평창동
# ..   ...    ...         ...           ...          ...            ...
# 419  강동구   성내2동  1174065000             6        37591   서울시 강동구 성내2동
# 420  강동구   성내3동  1174066000             7        33692   서울시 강동구 성내3동
# 421  강동구     길동  1174068500             7        21367     서울시 강동구 길동
# 422  강동구   둔촌1동  1174069000             7          308   서울시 강동구 둔촌1동
# 423  강동구   둔촌2동  1174070000             7        28318   서울시 강동구 둔촌2동
#
#              x           y
# 0    37.583776  126.970663
# 1    37.573878  126.970561
# 2    37.590765  126.981016
# ...
