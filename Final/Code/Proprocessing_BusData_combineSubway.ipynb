# %%
import pandas as pd
import os

# %%
bus = pd.read_csv("/content/drive/MyDrive/B A 데이터 모음/Final/dataset/지하철_버스위치데이터/bus_seoul.csv")
bus
# Out:
#        ARSID       표준ID           정류장명         X좌표        Y좌표
# 0       1001  100000001        종로2가사거리  126.987786  37.569764
# 1       1002  100000002    창경궁.서울대학교병원  126.996520  37.579179
# 2       1003  100000003      명륜3가.성대입구  126.998290  37.582709
# 3       1004  100000004       종로2가.삼일교  126.987507  37.568582
# 4       1005  100000005  혜화동로터리.여운형활동터  127.001694  37.586230
# ...      ...        ...            ...         ...        ...
# 11175  25995  124000334          우성아파트  127.139326  37.550442
# 11176  25996  124000333          우성아파트  127.140052  37.550620
# 11177  25997  124000332           조일약국  127.123477  37.533686
# 11178  25998  124000331           성내시장  127.125410  37.536199
# 11179  25999  124000330    천호우체국.로데오거리  127.127354  37.540390
#
# [11180 rows x 5 columns]

# %%
import pandas as pd

# %%
bus_local = pd.read_csv("/content/drive/MyDrive/B A 데이터 모음/Final/dataset/지하철_버스위치데이터/bus_seoul.csv")
bus_local
# Out:
#        ARSID       표준ID           정류장명         X좌표        Y좌표
# 0       1001  100000001        종로2가사거리  126.987786  37.569764
# 1       1002  100000002    창경궁.서울대학교병원  126.996520  37.579179
# 2       1003  100000003      명륜3가.성대입구  126.998290  37.582709
# 3       1004  100000004       종로2가.삼일교  126.987507  37.568582
# 4       1005  100000005  혜화동로터리.여운형활동터  127.001694  37.586230
# ...      ...        ...            ...         ...        ...
# 11175  25995  124000334          우성아파트  127.139326  37.550442
# 11176  25996  124000333          우성아파트  127.140052  37.550620
# 11177  25997  124000332           조일약국  127.123477  37.533686
# 11178  25998  124000331           성내시장  127.125410  37.536199
# 11179  25999  124000330    천호우체국.로데오거리  127.127354  37.540390
#
# [11180 rows x 5 columns]

# %%
bus_local_selected = bus_local[["정류장명",	"X좌표",	"Y좌표"]]


bus_local_selected = bus_local_selected.rename(columns={'정류장명': '역명'})
bus_local_selected
df = bus_local_selected[bus_local_selected['역명'] =="한성여객종점"]
df
# Out:
#           역명         X좌표        Y좌표
# 4109  한성여객종점  127.070007  37.638117
# 4110  한성여객종점  127.070732  37.637350
# 4163  한성여객종점  127.070588  37.637417

# %%
location_grouped_df = bus_local_selected.groupby('역명').mean().reset_index()
df2 = location_grouped_df [location_grouped_df ['역명'] =="한성여객종점"]
df2
# Out:
#           역명         X좌표        Y좌표
# 6473  한성여객종점  127.070443  37.637628

# %%
bus_local2 = bus_local[bus_local["정류장명"] == "(구)단대동주민센터"]
bus_local2
# Out:
# Empty DataFrame
# Columns: [ARSID, 표준ID, 정류장명, X좌표, Y좌표]
# Index: []

# %%
bus_Usage = pd.read_csv('/content/drive/MyDrive/B A 데이터 모음/Final/dataset/지하철_버스위치데이터/BUS_STATION_BOARDING_MONTH_2019/BUS_STATION_BOARDING_MONTH_201901.csv', encoding='cp949')
bus_Usage
# Out:
#              사용일자  노선번호                  노선명 버스정류장ARS번호              역명  \
# 0        20190101   100       100번(하계동~용산구청)      11428          한성여객종점
# 1        20190101   100       100번(하계동~용산구청)      11387         노원평생학습관
# 2        20190101   100       100번(하계동~용산구청)      11373             중계역
# 3        20190101   100       100번(하계동~용산구청)      11381      중계목화아파트4단지
# 4        20190101   100       100번(하계동~용산구청)      11311            인덕대학
# ...           ...   ...                  ...        ...             ...
# 1185092  20190131  동작01        동작01(달마사~대방역)      20799           건영아파트
# 1185093  20190131   542  542번(군포버스공영차고지~신사역)      57040            명학대교
# 1185094  20190131  서초02     서초02(교대역~서울고등학교)      22994          아크로비스타
# 1185095  20190131   761     761번(진관차고지~영등포역)      13111  연희104고지앞.구성산회관
# 1185096  20190131   542  542번(군포버스공영차고지~신사역)      57046            명학초교
#
#          승차총승객수  하차총승객수      등록일자
# 0            10       0  20190104
# ...

# %%
bus_Usage2= bus_Usage[bus_Usage["버스정류장ARS번호"] == "~"]
bus_Usage2
# Out:
#         버스정류장ARS번호             역명
# 652              ~   우신운수종점(종점가상)
# 1097             ~    도원교통차고지(가상)
# 1370             ~    중랑공영차고지(가상)
# 1527             ~  중랑공영차고지(기점가상)
# 1538             ~  중랑공영차고지(기점가상)
# ...            ...            ...
# 1182907          ~     김포교통(기점가상)
# 1182924          ~  보성운수기종점(기점가상)
# 1183418          ~      우이동종점(가상)
# 1183954          ~   개포동차고지(종점가상)
# 1184282          ~      상암차고지(가상)
#
# [6239 rows x 2 columns]

# %%
# #CSV 파일이 있는 디렉토리 설정
# directory = '/content/drive/MyDrive/B A 데이터 모음/Final/dataset/지하철_버스위치데이터/BUS_STATION_BOARDING_MONTH_2019'

# # 디렉토리에서 모든 CSV 파일 목록을 가져옴
# file_list = [file for file in os.listdir(directory) if file.endswith('.csv')]

# # 모든 CSV 파일을 DataFrame으로 읽어 들임
# dataframes = [pd.read_csv(os.path.join(directory, file), encoding='cp949') for file in file_list]


# # 모든 DataFrame을 하나로 병합
# combined_df = pd.concat(dataframes)

# # '버스정류장ARS번호'를 기준으로 그룹화하고 '승차총승객수', '하차총승객수'를 합산
# grouped_df = combined_df.groupby('역명').agg({'승차총승객수': 'sum', '하차총승객수': 'sum'}).reset_index()

# # 결과를 새로운 CSV 파일로 저장
# grouped_df.to_csv('/content/drive/MyDrive/B A 데이터 모음/Final/dataset/지하철_버스위치데이터/real_grouped_bus_data.csv', index=False)

# %%
grouped_df = pd.read_csv("/content/drive/MyDrive/B A 데이터 모음/Final/dataset/지하철_버스위치데이터/real_grouped_bus_data.csv")
grouped_df
# Out:
#                    역명  승차총승객수  하차총승객수
# 0          (구)단대동주민센터   84656   78652
# 1             (구)태풍약국  258891   37742
# 2                11단지   70584   13197
# 3     123전자타운.2001아울렛  253880  287488
# 4           12번지건영아파트  129440  145195
# ...               ...     ...     ...
# 8246  힐스테이트송파.송파한라비발디    6210  126410
# 8247          힐스테이트입구   18292   26147
# 8248               힐탑    1815    6160
# 8249             힐튼호텔  116642  267261
# 8250       힐튼호텔.현대아파트   92999   67747
#
# [8251 rows x 3 columns]

# %%
grouped_df2 = grouped_df[grouped_df["역명"]	=="한성여객종점"]
grouped_df2
# Out:
#           역명  승차총승객수  하차총승객수
# 7748  한성여객종점  212053  203606

# %%
# 두 데이터 세트를 '역명'를 기준으로 병합
merged_df = pd.merge(grouped_df, location_grouped_df, on='역명', how='left')
merged_df

# merged_df2 = merged_df[merged_df["역명"]	== "한성여객종점"]
# merged_df2
# Out:
#                    역명  승차총승객수  하차총승객수         X좌표        Y좌표
# 0          (구)단대동주민센터   84656   78652         NaN        NaN
# 1             (구)태풍약국  258891   37742         NaN        NaN
# 2                11단지   70584   13197         NaN        NaN
# 3     123전자타운.2001아울렛  253880  287488  126.862107  37.497222
# 4           12번지건영아파트  129440  145195  126.914023  37.629075
# ...               ...     ...     ...         ...        ...
# 8246  힐스테이트송파.송파한라비발디    6210  126410  127.141905  37.480798
# 8247          힐스테이트입구   18292   26147  127.027583  37.606174
# 8248               힐탑    1815    6160  126.969041  37.611640
# 8249             힐튼호텔  116642  267261  126.976662  37.556318
# 8250       힐튼호텔.현대아파트   92999   67747  126.936517  37.589115
#
# [8251 rows x 5 columns]

# %%
non_nan_rows = merged_df[merged_df['X좌표'].notna() & merged_df['Y좌표'].notna()]
non_nan_rows
# Out:
#                    역명  승차총승객수  하차총승객수         X좌표        Y좌표
# 3     123전자타운.2001아울렛  253880  287488  126.862107  37.497222
# 4           12번지건영아파트  129440  145195  126.914023  37.629075
# 6              14단지상가  127751  126417  127.059583  37.669808
# 7              1호선구일역   78332  184397  126.872224  37.495350
# 9          2001아울렛중계점   20191   35707  127.067681  37.641648
# ...               ...     ...     ...         ...        ...
# 8246  힐스테이트송파.송파한라비발디    6210  126410  127.141905  37.480798
# 8247          힐스테이트입구   18292   26147  127.027583  37.606174
# 8248               힐탑    1815    6160  126.969041  37.611640
# 8249             힐튼호텔  116642  267261  126.976662  37.556318
# 8250       힐튼호텔.현대아파트   92999   67747  126.936517  37.589115
#
# [6517 rows x 5 columns]

# %%
# X좌표와 Y좌표가 모두 NaN인 행 찾기
nan_rows = merged_df[merged_df['X좌표'].isna() & merged_df['Y좌표'].isna()]

# 결과 출력
nan_rows
# Out:
#                역명  승차총승객수  하차총승객수  X좌표  Y좌표
# 0      (구)단대동주민센터   84656   78652  NaN  NaN
# 1         (구)태풍약국  258891   37742  NaN  NaN
# 2            11단지   70584   13197  NaN  NaN
# 5       13단지아파트입구   65105   99397  NaN  NaN
# 8        2.7호선대림역  264114  223836  NaN  NaN
# ...           ...     ...     ...  ...  ...
# 8230        희망양로원   22592   12317  NaN  NaN
# 8232  흰돌5단지.서안아파트    2289   54100  NaN  NaN
# 8234      흰돌마을(중)   12774   36673  NaN  NaN
# 8235   흰돌마을.서안아파트   41773    3322  NaN  NaN
# 8236        흰돌아파트   21497   15786  NaN  NaN
#
# [1734 rows x 5 columns]

# %%
import requests

def geocode_address(address):
    api_key = 'AIzaSyBygRp967Ub0GG0DVVYOm6OOdivESjR3RQ'
    base_url = 'https://maps.googleapis.com/maps/api/geocode/json'

    params = {
        'address': address,
        'key': api_key,
    }

    response = requests.get(base_url, params=params)
    data = response.json()

    if data['status'] == 'OK':
        location = data['results'][0]['geometry']['location']
        latitude = location['lat']
        longitude = location['lng']
        return latitude, longitude
    else:
        return None, None

# %%
for index, row in nan_rows.iterrows():
    coordinates = geocode_address(row['역명'])
    if coordinates:
        # print(f'주소 "{address}"의 지리적 좌표: {coordinates[0]}, {coordinates[1]}')
        nan_rows.at[index, 'X좌표'] = coordinates[1]
        nan_rows.at[index, 'Y좌표'] = coordinates[0]
    else:
        # print('주소를 변환할 수 없습니다.')
        nan_rows.at[index, 'X좌표'] = None
        nan_rows.at[index, 'Y좌표'] = None

# %%
# nan_row에서 아예 nan 인거 날리고
# non nan 하고 nan 하고 합친다

non_nan = nan_rows[nan_rows['X좌표'].notna() & nan_rows['Y좌표'].notna()]

non_nan
# Out:
#                    역명  승차총승객수  하차총승객수         X좌표        Y좌표
# 0          (구)단대동주민센터   84656   78652  127.158171  37.447767
# 1             (구)태풍약국  258891   37742  128.558397  37.636611
# 5           13단지아파트입구   65105   99397  126.934380  37.371205
# 8            2.7호선대림역  264114  223836  126.894961  37.492504
# 17    3단지.소월아파트.다산아파트   78929    3522  126.932831  37.353089
# ...               ...     ...     ...         ...        ...
# 8225          흥도동주민센터   21608   46562  126.851778  37.644628
# 8229            흥진중학교   16488   12018  126.928586  37.352928
# 8232      흰돌5단지.서안아파트    2289   54100  126.785789  37.640957
# 8234          흰돌마을(중)   12774   36673  126.781510  37.648087
# 8235       흰돌마을.서안아파트   41773    3322  126.785956  37.641610
#
# [1295 rows x 5 columns]

# %%
merged_final = pd.concat([non_nan_rows, non_nan], ignore_index=True)
merged_final
# Out:
#                    역명  승차총승객수  하차총승객수         X좌표        Y좌표
# 0     123전자타운.2001아울렛  253880  287488  126.862107  37.497222
# 1           12번지건영아파트  129440  145195  126.914023  37.629075
# 2              14단지상가  127751  126417  127.059583  37.669808
# 3              1호선구일역   78332  184397  126.872224  37.495350
# 4          2001아울렛중계점   20191   35707  127.067681  37.641648
# ...               ...     ...     ...         ...        ...
# 7807          흥도동주민센터   21608   46562  126.851778  37.644628
# 7808            흥진중학교   16488   12018  126.928586  37.352928
# 7809      흰돌5단지.서안아파트    2289   54100  126.785789  37.640957
# 7810          흰돌마을(중)   12774   36673  126.781510  37.648087
# 7811       흰돌마을.서안아파트   41773    3322  126.785956  37.641610
#
# [7812 rows x 5 columns]

# %%
 #merged_final.to_csv('/content/drive/MyDrive/B A 데이터 모음/Final/dataset/지하철_버스위치데이터/final_subway_data.csv', index=False)

# %%
merged_final['총승객수'] = merged_final['승차총승객수'] + merged_final['하차총승객수']

rerange_colunms = ["역명", "총승객수","X좌표","Y좌표"]
merged_final = merged_final[rerange_colunms]
merged_final
# Out:
#                    역명    총승객수         X좌표        Y좌표
# 0     123전자타운.2001아울렛  541368  126.862107  37.497222
# 1           12번지건영아파트  274635  126.914023  37.629075
# 2              14단지상가  254168  127.059583  37.669808
# 3              1호선구일역  262729  126.872224  37.495350
# 4          2001아울렛중계점   55898  127.067681  37.641648
# ...               ...     ...         ...        ...
# 7807          흥도동주민센터   68170  126.851778  37.644628
# 7808            흥진중학교   28506  126.928586  37.352928
# 7809      흰돌5단지.서안아파트   56389  126.785789  37.640957
# 7810          흰돌마을(중)   49447  126.781510  37.648087
# 7811       흰돌마을.서안아파트   45095  126.785956  37.641610
#
# [7812 rows x 4 columns]

# %%
merged_final = merged_final.rename(columns={
    "총승객수" : "승차총승객수",
    'X좌표': 'y',  # 'X좌표'를 'Latitude'로 변경
    'Y좌표': 'x'  # 'Y좌표'를 'Longitude'로 변경
})

rearrange = ["역명",	"승차총승객수",	"x","y"]
merged_final= merged_final[rearrange]
merged_final
# Out:
#                    역명  승차총승객수          x           y
# 0     123전자타운.2001아울렛  541368  37.497222  126.862107
# 1           12번지건영아파트  274635  37.629075  126.914023
# 2              14단지상가  254168  37.669808  127.059583
# 3              1호선구일역  262729  37.495350  126.872224
# 4          2001아울렛중계점   55898  37.641648  127.067681
# ...               ...     ...        ...         ...
# 7807          흥도동주민센터   68170  37.644628  126.851778
# 7808            흥진중학교   28506  37.352928  126.928586
# 7809      흰돌5단지.서안아파트   56389  37.640957  126.785789
# 7810          흰돌마을(중)   49447  37.648087  126.781510
# 7811       흰돌마을.서안아파트   45095  37.641610  126.785956
#
# [7812 rows x 4 columns]

# %%
subway = pd.read_csv("/content/drive/MyDrive/B A 데이터 모음/Final/dataset/지하철_버스위치데이터/subway.csv")
subway
# Out:
#      Unnamed: 0       역명      승차총승객수      하차총승객수        총승객수  \
# 0             0     가락시장   6520692.0   6838458.0  13359150.0
# 1             1  가산디지털단지  20342388.0  21261918.0  41604306.0
# 2             2       가양   7630162.0   7368226.0  14998388.0
# 3             3       가좌   1994546.0   1834580.0   3829126.0
# 4             4       강남  36432679.0  37197520.0  73630199.0
# ..          ...      ...         ...         ...         ...
# 282         282      화랑대   4761392.0   3642128.0   8403520.0
# 283         283       회기  10821267.0  10488582.0  21309849.0
# 284         284       회현  11125865.0  11789883.0  22915748.0
# 285         285    효창공원앞   3701915.0   3575201.0   7277116.0
# 286         286       흑석   3693368.0   3769721.0   7463089.0
#
#                 address                coordinates
# 0    서울특별시 송파구 송파대로 257  (37.4929144, 127.1182155)
# 1     서울특별시 금천구 벚꽃로 309  (37.4824123, 126.8822401)
# 2     서울특별시 강서구 양천로 485  (37.5617576, 126.8539972)
# ...

# %%
# Convert 'coordinates' column to string type
subway['coordinates'] = subway['coordinates'].astype(str)

# Split the 'coordinates' column and assign to 'x' and 'y' columns
subway[['x', 'y']] = subway['coordinates'].str.strip('()').str.split(', ', expand=True).astype(float)

subway
# Out:
# <ipython-input-86-278d1a8a576c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subway['coordinates'] = subway['coordinates'].astype(str)
# <ipython-input-86-278d1a8a576c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subway[['x', 'y']] = subway['coordinates'].str.strip('()').str.split(', ', expand=True).astype(float)
# <ipython-input-86-278d1a8a576c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
subway_selected_columns = ["역명",	"승차총승객수", "x", "y"]
subway = subway[subway_selected_columns]
subway
# Out:
#           역명      승차총승객수          x           y
# 0       가락시장   6520692.0  37.492914  127.118216
# 1    가산디지털단지  20342388.0  37.482412  126.882240
# 2         가양   7630162.0  37.561758  126.853997
# 3         가좌   1994546.0  37.568883  126.915167
# 4         강남  36432679.0  37.497056  127.028181
# ..       ...         ...        ...         ...
# 282      화랑대   4761392.0  37.619895  127.083287
# 283       회기  10821267.0  37.590796  127.059313
# 284       회현  11125865.0  37.558857  126.977648
# 285    효창공원앞   3701915.0  37.539579  126.961229
# 286       흑석   3693368.0  37.508536  126.964015
#
# [287 rows x 4 columns]

# %%
real_final_merged_df = pd.concat([subway, merged_final], ignore_index=True)
real_final_merged_df
# Out:
#                역명      승차총승객수          x           y
# 0            가락시장   6520692.0  37.492914  127.118216
# 1         가산디지털단지  20342388.0  37.482412  126.882240
# 2              가양   7630162.0  37.561758  126.853997
# 3              가좌   1994546.0  37.568883  126.915167
# 4              강남  36432679.0  37.497056  127.028181
# ...           ...         ...        ...         ...
# 8094      흥도동주민센터     68170.0  37.644628  126.851778
# 8095        흥진중학교     28506.0  37.352928  126.928586
# 8096  흰돌5단지.서안아파트     56389.0  37.640957  126.785789
# 8097      흰돌마을(중)     49447.0  37.648087  126.781510
# 8098   흰돌마을.서안아파트     45095.0  37.641610  126.785956
#
# [8099 rows x 4 columns]

# %%
# real_final_merged_df.to_csv('/content/drive/MyDrive/B A 데이터 모음/Final/dataset/지하철_버스위치데이터/final_subway_bus_data.csv', index=False)

# %%
# 테스트
# df4 = real_final_merged_df[real_final_merged_df["역명"] =="~"]
# df4
# Out:
# Empty DataFrame
# Columns: [역명, 승차총승객수, x, y]
# Index: []

# %%
# nan 체크
nan_check = real_final_merged_df.isna().any()
nan_check
# Out:
# 역명        False
# 승차총승객수    False
# x         False
# y         False
# dtype: bool
